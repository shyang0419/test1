# %%
a= 'Andrew_HBXX-6516DS-VTM'

b = 'Andrew_HBXX-6516DS-VTM'
a ==b
# Out:
# True

# %%
b[0].split(' ')
b
b[0]
# Out:
# 'asdf'

# %%
c = a[0]+' '+a[1]
c
# Out:
# 'FSMF FHEB'

# %%
split(c,' ')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2002935bd1d4> in <module>
# ----> 1 split(c,' ')
#
# NameError: name 'split' is not defined
